# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariam-Idris/Grocery-Agent/blob/main/mariam_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
departure = "Karachi"
destination = "Islamabad"

travel_cost = 25000

budget = 30000

print("Departure:", departure)
print("Destination:", destination)

if budget >= travel_cost:
    print("Travel plan is available within your budget")
else:
    print("Travel plan is not available within your budget")
# Out:
# Departure: Karachi
# Destination: Islamabad
# Travel plan is available within your budget
