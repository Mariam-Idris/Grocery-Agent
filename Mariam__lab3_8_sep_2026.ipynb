# %%
# !pip install -U google-genai

from google import genai
client = genai.Client(api_key="AQ.Ab8RN6LjfjIkN6tJlQEEvqdwrP1C-yMXTO37-nplyBWX4QRSfg")

MODEL = "gemini-3-flash-preview"

# %%
# !pip install -U google-genai

from google import genai

# %%
while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)

# %%
# !pip install -U google-genai

from google import genai

# %%
def grocery_agent(user_input):

    prompt = f"""
You are a Grocery Recommendation Agent.

Help the user select suitable grocery items based on their needs.

Provide recommendations with clear headings:

1. Grocery Category
2. Recommended Items
3. Budget-Friendly Options
4. Quantity Suggestions
    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = grocery_agent(user)
        print("\nAgent:\n", reply, "\n")

    exceipt Exception as e:
        print("Error:", e)
# Out:
# You: hello
# Error: name 'client' is not defined
